# %%
import pandas as pd
pd.set_option("display.max_rows",None)
df_1 = pd.read_csv("CSDpop.csv")
df_2 = pd.read_csv("kijiji_dataset_01.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
merged_df = df_1.merge(df_2, on = "CSDUID", how = "left")

# %%
merged_df = merged_df.drop(['Title','adId','Location','URL','Date Posted'],axis=1)

# %%
obj_df=merged_df

# %%
str_num_conv = {"Type":{"Apartment": 1,"House": 2,"Basement": 3,"Condo": 4 ,
                            "Townhouse": 5 ,"Duplex/Triplex": 6}}
obj_df = obj_df.replace(str_num_conv)

obj_df['Type']=obj_df['Type'].astype(float)

# %%
str_num_conv = {"Bedrooms":{"Bedrooms: 2": 2,"Bedrooms: 1": 1,"Bedrooms: 3": 3,"Bedrooms: 4": 4 ,
                            "Bedrooms: 1 + Den": 1.5 ,"Bedrooms: Bachelor/Studio": 0.5 ,
                            "Bedrooms: 2 + Den": 2.5 ,"Bedrooms: 3 + Den": 3.5 ,"Bedrooms: 4 + Den": 4.5 ,"Bedrooms: 5+": 5},
  }

# %%
obj_df = obj_df.replace(str_num_conv)
obj_df['Bedrooms']=obj_df['Bedrooms'].astype(float)
obj_df.head()
# Out:
#     CSDUID  Population          CSDNAME   Latitude  Longitude  Type   Price  \
# 0  3501005       14211  South Glengarry  45.256161 -74.595385   1.0  $1,425
# 1  3501005       14211  South Glengarry  45.192003 -74.374604   1.0  $1,100
# 2  3501005       14211  South Glengarry  45.146672 -74.579565   2.0  $2,700
# 3  3501005       14211  South Glengarry  45.143726 -74.502708   2.0  $1,200
# 4  3501005       14211  South Glengarry  45.068973 -74.542873   2.0  $4,000
#
#    Bedrooms       Bathrooms Hydro Heat Water   Size Agreement Type
# 0       2.0    Bathrooms: 1     N    Y     Y    950         1 Year
# 1       2.0    Bathrooms: 1     N    N     Y    780         1 Year
# 2       3.0  Bathrooms: 2.5     N    Y     Y  2,200         1 Year
# 3       2.0  Bathrooms: 1.5     N    N     Y    900         1 Year
# 4       2.5    Bathrooms: 3     N    Y     Y  1,400         1 Year

# %%
str_num_conv = {"Bathrooms":{"Bathrooms: 1": 1,"Bathrooms: 2": 2,"Bathrooms: 2.5": 2.5,"Bathrooms: 1.5": 1.5 ,
                            "Bathrooms: 3": 3 ,"Bathrooms: 3.5": 3.5 ,
                            "Bathrooms: 4": 4 ,"Bathrooms: 5": 5 ,"Bathrooms: 4.5": 4.5 ,"Bathrooms: 5.5": 5.5, "Bathrooms: 6+":6},
  }

# %%
obj_df = obj_df.replace(str_num_conv)
obj_df['Bedrooms']=obj_df['Bedrooms'].astype(float)
obj_df.head()
# Out:
#     CSDUID  Population          CSDNAME   Latitude  Longitude  Type   Price  \
# 0  3501005       14211  South Glengarry  45.256161 -74.595385   1.0  $1,425
# 1  3501005       14211  South Glengarry  45.192003 -74.374604   1.0  $1,100
# 2  3501005       14211  South Glengarry  45.146672 -74.579565   2.0  $2,700
# 3  3501005       14211  South Glengarry  45.143726 -74.502708   2.0  $1,200
# 4  3501005       14211  South Glengarry  45.068973 -74.542873   2.0  $4,000
#
#    Bedrooms  Bathrooms Hydro Heat Water   Size Agreement Type
# 0       2.0        1.0     N    Y     Y    950         1 Year
# 1       2.0        1.0     N    N     Y    780         1 Year
# 2       3.0        2.5     N    Y     Y  2,200         1 Year
# 3       2.0        1.5     N    N     Y    900         1 Year
# 4       2.5        3.0     N    Y     Y  1,400         1 Year

# %%
str_num_conv = {"Hydro":{"N": 0,"Y": 1}}
obj_df = obj_df.replace(str_num_conv)
obj_df['Hydro']=obj_df['Hydro'].astype(object)

obj_df.head()
# Out:
#     CSDUID  Population          CSDNAME   Latitude  Longitude  Type   Price  \
# 0  3501005       14211  South Glengarry  45.256161 -74.595385   1.0  $1,425
# 1  3501005       14211  South Glengarry  45.192003 -74.374604   1.0  $1,100
# 2  3501005       14211  South Glengarry  45.146672 -74.579565   2.0  $2,700
# 3  3501005       14211  South Glengarry  45.143726 -74.502708   2.0  $1,200
# 4  3501005       14211  South Glengarry  45.068973 -74.542873   2.0  $4,000
#
#    Bedrooms  Bathrooms Hydro Heat Water   Size Agreement Type
# 0       2.0        1.0   0.0    Y     Y    950         1 Year
# 1       2.0        1.0   0.0    N     Y    780         1 Year
# 2       3.0        2.5   0.0    Y     Y  2,200         1 Year
# 3       2.0        1.5   0.0    N     Y    900         1 Year
# 4       2.5        3.0   0.0    Y     Y  1,400         1 Year

# %%
str_num_conv = {"Heat":{"N": 0,"Y": 1}}
obj_df = obj_df.replace(str_num_conv)
obj_df['Heat']=obj_df['Heat'].astype(object)

obj_df.head()
# Out:
#     CSDUID  Population          CSDNAME   Latitude  Longitude  Type   Price  \
# 0  3501005       14211  South Glengarry  45.256161 -74.595385   1.0  $1,425
# 1  3501005       14211  South Glengarry  45.192003 -74.374604   1.0  $1,100
# 2  3501005       14211  South Glengarry  45.146672 -74.579565   2.0  $2,700
# 3  3501005       14211  South Glengarry  45.143726 -74.502708   2.0  $1,200
# 4  3501005       14211  South Glengarry  45.068973 -74.542873   2.0  $4,000
#
#    Bedrooms  Bathrooms Hydro Heat Water   Size Agreement Type
# 0       2.0        1.0   0.0  1.0     Y    950         1 Year
# 1       2.0        1.0   0.0  0.0     Y    780         1 Year
# 2       3.0        2.5   0.0  1.0     Y  2,200         1 Year
# 3       2.0        1.5   0.0  0.0     Y    900         1 Year
# 4       2.5        3.0   0.0  1.0     Y  1,400         1 Year

# %%
str_num_conv = {"Water":{"N": 0,"Y": 1}}
obj_df = obj_df.replace(str_num_conv)
obj_df['Water']=obj_df['Water'].astype(object)
obj_df.head()
# Out:
#     CSDUID  Population          CSDNAME   Latitude  Longitude  Type   Price  \
# 0  3501005       14211  South Glengarry  45.256161 -74.595385   1.0  $1,425
# 1  3501005       14211  South Glengarry  45.192003 -74.374604   1.0  $1,100
# 2  3501005       14211  South Glengarry  45.146672 -74.579565   2.0  $2,700
# 3  3501005       14211  South Glengarry  45.143726 -74.502708   2.0  $1,200
# 4  3501005       14211  South Glengarry  45.068973 -74.542873   2.0  $4,000
#
#    Bedrooms  Bathrooms Hydro Heat Water   Size Agreement Type
# 0       2.0        1.0   0.0  1.0   1.0    950         1 Year
# 1       2.0        1.0   0.0  0.0   1.0    780         1 Year
# 2       3.0        2.5   0.0  1.0   1.0  2,200         1 Year
# 3       2.0        1.5   0.0  0.0   1.0    900         1 Year
# 4       2.5        3.0   0.0  1.0   1.0  1,400         1 Year

# %%
obj_df['Price'] = obj_df['Price'].str.replace('$', '')
obj_df['Price'] = obj_df['Price'].str.replace(',', '')
obj_df['Price'] = pd.to_numeric(obj_df['Price'], errors='coerce')
obj_df['Price']=obj_df['Price'].astype(float)
obj_df.head()
# Out:
# <ipython-input-91-eb49379aaa60>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   obj_df['Price'] = obj_df['Price'].str.replace('$', '')
#     CSDUID  Population          CSDNAME   Latitude  Longitude  Type   Price  \
# 0  3501005       14211  South Glengarry  45.256161 -74.595385   1.0  1425.0
# 1  3501005       14211  South Glengarry  45.192003 -74.374604   1.0  1100.0
# 2  3501005       14211  South Glengarry  45.146672 -74.579565   2.0  2700.0
# 3  3501005       14211  South Glengarry  45.143726 -74.502708   2.0  1200.0
# 4  3501005       14211  South Glengarry  45.068973 -74.542873   2.0  4000.0
#
#    Bedrooms  Bathrooms Hydro Heat Water   Size Agreement Type
# 0       2.0        1.0   0.0  1.0   1.0    950         1 Year
# 1       2.0        1.0   0.0  0.0   1.0    780         1 Year
# ...

# %%
obj_df.head(10)
# Out:
#     CSDUID  Population          CSDNAME   Latitude  Longitude  Type   Price  \
# 0  3501005       14211  South Glengarry  45.256161 -74.595385   1.0  1425.0
# 1  3501005       14211  South Glengarry  45.192003 -74.374604   1.0  1100.0
# 2  3501005       14211  South Glengarry  45.146672 -74.579565   2.0  2700.0
# 3  3501005       14211  South Glengarry  45.143726 -74.502708   2.0  1200.0
# 4  3501005       14211  South Glengarry  45.068973 -74.542873   2.0  4000.0
# 5  3501005       14211  South Glengarry  45.059039 -74.558464   1.0  1695.0
# 6  3501005       14211  South Glengarry  45.135981 -74.619588   1.0  1095.0
# 7  3501005       14211  South Glengarry  45.256161 -74.595385   2.0  2180.0
# 8  3501005       14211  South Glengarry  45.154592 -74.710634   5.0  2400.0
# 9  3501007        1817              NaN        NaN        NaN   NaN     NaN
#
#    Bedrooms  Bathrooms Hydro Heat Water   Size Agreement Type
# 0       2.0        1.0   0.0  1.0   1.0    950         1 Year
# ...

# %%
str_num_conv = {"Heat":{"N": 0,"Y": 1}}
obj_df = obj_df.replace(str_num_conv)
obj_df['Heat']=obj_df['Heat'].astype(float)

# %%
str_num_conv = {"Water":{"N": 0,"Y": 1}}
obj_df = obj_df.replace(str_num_conv)
obj_df['Water']=obj_df['Water'].astype(float)

# %%
obj_df["Size"] = pd.to_numeric(obj_df["Size"], errors='coerce')

# %%
#obj_df["Size"].fillna(obj_df["Size"].mean,inplace= True)
mean_size = obj_df["Size"].mean()
obj_df['Size'].replace(to_replace=pd.NA, value=mean_size, inplace=True)

# %%
obj_df.dtypes
# Out:
# CSDUID              int64
# Population          int64
# CSDNAME            object
# Latitude          float64
# Longitude         float64
# Type              float64
# Price             float64
# Bedrooms          float64
# Bathrooms         float64
# Hydro              object
# Heat              float64
# Water             float64
# Size              float64
# Agreement Type     object
# dtype: object

# %%
obj_df = obj_df[obj_df["Size"] > 300]

# %%
obj_df = obj_df[obj_df["Size"] < 9000]

# %%
obj_df = obj_df.reset_index(drop=True)

# %%
obj_df.to_csv("data_set_ML_01.csv", index= False)

# %%
min_population  = 0
max_population = 10000

smallcomunity_df = obj_df[(obj_df["Population"]>= min_population) & (obj_df["Population"]<= max_population)]

# %%
#smallcomunity_df.to_csv("small_community_EDA.csv")

# %%
min_population  = 10001
max_population = 100000

mediumcomunity_df = obj_df[(obj_df["Population"]>= min_population) & (obj_df["Population"]<= max_population)]

# %%
#mediumcomunity_df.to_csv("Medium_community_EDA.csv")

# %%
min_population  = 100001
max_population = 500000

largecomunity_df = obj_df[(obj_df["Population"]>= min_population) & (obj_df["Population"]<= max_population)]

# %%
#largecomunity_df.to_csv("Large_commuity_EDA")

# %%
min_population  =500000
very_large_comunity_df = obj_df[(obj_df["Population"]>= min_population)]

# %%
#very_large_comunity_df.to_csv("Very_large_community_EDA.csv")

# %%
corr_df = smallcomunity_df[["Population","Type","Size","Price"]]
corr_maxtix = corr_df.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,5))
sns.heatmap(corr_maxtix, annot= True, cmap = "coolwarm", linewidths=0.5)
plt.title("Heat Map")
plt.show()
